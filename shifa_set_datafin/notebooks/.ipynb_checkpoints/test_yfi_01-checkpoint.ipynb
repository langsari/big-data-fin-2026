# %%
# !pip install --upgrade yfinance
# !pip install pandas
# Out:
# Requirement already satisfied: yfinance in d:\anaconda\lib\site-packages (1.2.0)
# Requirement already satisfied: pandas>=1.3.0 in d:\anaconda\lib\site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in d:\anaconda\lib\site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: requests>=2.31 in d:\anaconda\lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in d:\anaconda\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\anaconda\lib\site-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in d:\anaconda\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in d:\anaconda\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in d:\anaconda\lib\site-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\anaconda\lib\site-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in d:\anaconda\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in d:\anaconda\lib\site-packages (from yfinance) (5.29.3)
# Requirement already satisfied: websockets>=13.0 in d:\anaconda\lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in d:\anaconda\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in d:\anaconda\lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\anaconda\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\anaconda\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import yfinance as yf
import psycopg2

# เทสต์แค่ 5 ตัวที่เป็นหุ้นใหญ่ (ถ้า 5 ตัวนี้ยังไม่ได้ แปลว่าปัญหาอยู่ที่ yfinance ไม่ใช่ที่ Database)
test_symbols = ["PTT", "AOT", "CPALL", "ADVANC", "DELTA"]

print("🔍 กำลังทดสอบดึงข้อมูลแบบละเอียด...")

for sym in test_symbols:
    try:
        print(f"\nกำลังดึงข้อมูล: {sym}.BK")
        ticker = yf.Ticker(f"{sym}.BK")
        
        # ลองดึงข้อมูล info ออกมาดูตรงๆ
        info = ticker.info
        
        sector = info.get('sector', 'ไม่พบข้อมูล Sector')
        mcap = info.get('marketCap', 'ไม่พบข้อมูล Market Cap')
        
        print(f"✅ สำเร็จ! -> Sector: {sector}, Market Cap: {mcap}")
        
    except Exception as e:
        # คราวนี้ถ้าพัง มันจะโชว์ Error ออกมาสีแดงๆ ให้เราเห็นเลย
        print(f"❌ พังตรงนี้! -> {e}")
# Out:
# 🔍 กำลังทดสอบดึงข้อมูลแบบละเอียด...
#
# กำลังดึงข้อมูล: PTT.BK
# ✅ สำเร็จ! -> Sector: Energy, Market Cap: 1033838264320
#
# กำลังดึงข้อมูล: AOT.BK
# ✅ สำเร็จ! -> Sector: Industrials, Market Cap: 807142031360
#
# กำลังดึงข้อมูล: CPALL.BK
# ✅ สำเร็จ! -> Sector: Consumer Defensive, Market Cap: 463606153216
#
# กำลังดึงข้อมูล: ADVANC.BK
# ✅ สำเร็จ! -> Sector: Communication Services, Market Cap: 1156967563264
#
# กำลังดึงข้อมูล: DELTA.BK
# ✅ สำเร็จ! -> Sector: Industrials, Market Cap: 3180823052288

# %%
import yfinance as yf
import psycopg2
import time

# 1. เชื่อมต่อ Database
conn = psycopg2.connect(host="127.0.0.1", database="thai_stocks_db", user="postgres", password="Shifa.326459")
conn.autocommit = True
cur = conn.cursor()

print("🔧 กำลังอัปเดตโครงสร้าง Database ให้รองรับ Market Cap...")

# 2. เพิ่มคอลัมน์ market_cap 
cur.execute("CREATE TABLE IF NOT EXISTS sectors (sector_id SERIAL PRIMARY KEY, sector_name VARCHAR(100) UNIQUE NOT NULL);")
cur.execute("CREATE TABLE IF NOT EXISTS stocks (symbol VARCHAR(20) PRIMARY KEY, sector_id INTEGER REFERENCES sectors(sector_id));")

cur.execute("ALTER TABLE stocks ADD COLUMN IF NOT EXISTS market_cap NUMERIC;")

print("✅ อัปเดตโครงสร้าง Database สำเร็จ!")

# 3. เริ่มดึงข้อมูล
all_thai_symbols = [
    "ADVANC", "AOT", "BBL", "BDMS", "BEM", "BGRIM", "BH", "BTS", "CBG", "CPALL", 
    "CPF", "CPN", "CRC", "DELTA", "EA", "EGCO", "GLOBAL", "GPSC", "GULF", "HMPRO", 
    "INTUCH", "IVL", "KBANK", "KTB", "KTC", "LH", "MINT", "MTC", "OR", "OSP", 
    "PTT", "PTTEP", "PTTGC", "RATCH", "SAWAD", "SCB", "SCC", "SCGP", "TISCO", "TOP", 
    "TRUE", "TTB", "TU", "WHA", "AMATA", "AP", "AWC", "BAM", "BANPU", "BCH", 
    "BCP", "BCPG", "BLA", "BPP", "CENTEL", "CHG", "CK", "CKP", "COM7", "DOHOME", 
    "EPG", "ERW", "FORTH", "HANA", "ICHI", "ILM", "JAS", "JMART", "JMT", 
    "KCE", "KKP", "MEGA", "ONEE", "ORI", "PLANB", "PSL", "PTG", "QH", "RBF", 
    "RCL", "RS", "SABINA", "SINGER", "SIRI", "SPALI", "SPRC", "STA", "STARK", "STEC", 
    "STGT", "SUPER", "SYNEX", "TASCO", "TCAP", "THANI", "THCOM", "THG", "TIDLOR", "TIPH", 
    "TKN", "TQM", "TTA", "VGI", "WICE", "XPG"
]

print(f"⏳ เริ่มต้นดึงข้อมูลหุ้น {len(all_thai_symbols)} ตัว ลง Database...")

success_count = 0

for sym in all_thai_symbols:
    try:
        ticker = yf.Ticker(f"{sym}.BK")
        info = ticker.info
        
        if 'marketCap' in info and info['marketCap'] is not None:
            sector_name = info.get('sector', 'Unknown')
            market_cap = info.get('marketCap', 0)
            
            # บันทึก Sector
            cur.execute("""
                INSERT INTO sectors (sector_name) VALUES (%s) 
                ON CONFLICT (sector_name) DO NOTHING;
            """, (sector_name,))
            
            cur.execute("SELECT sector_id FROM sectors WHERE sector_name = %s;", (sector_name,))
            s_id = cur.fetchone()[0]
            
            # บันทึก หุ้น
            cur.execute("""
                INSERT INTO stocks (symbol, sector_id, market_cap)
                VALUES (%s, %s, %s)
                ON CONFLICT (symbol) DO UPDATE 
                SET sector_id = EXCLUDED.sector_id, market_cap = EXCLUDED.market_cap;
            """, (sym, s_id, market_cap))
            
            success_count += 1
            print(f"✅ บันทึก {sym} สำเร็จ! (Sector: {sector_name})")
            
        time.sleep(0.1)
        
    except Exception as e:
        print(f"⚠️ ข้าม {sym} -> หาข้อมูลไม่พบ หรือ Error: {e}")

print(f"\n🎉 สำเร็จแล้ว! ดึงข้อมูลและบันทึกลง Database ได้ทั้งหมด {success_count} ตัว!")
# Out:
# 🔧 กำลังอัปเดตโครงสร้าง Database ให้รองรับ Market Cap...
# ✅ อัปเดตโครงสร้าง Database สำเร็จ!
# ⏳ เริ่มต้นดึงข้อมูลหุ้น 105 ตัว ลง Database...
# ✅ บันทึก ADVANC สำเร็จ! (Sector: Communication Services)
# ✅ บันทึก AOT สำเร็จ! (Sector: Industrials)
# ✅ บันทึก BBL สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก BDMS สำเร็จ! (Sector: Healthcare)
# ✅ บันทึก BEM สำเร็จ! (Sector: Industrials)
# ✅ บันทึก BGRIM สำเร็จ! (Sector: Utilities)
# ✅ บันทึก BH สำเร็จ! (Sector: Healthcare)
# ✅ บันทึก BTS สำเร็จ! (Sector: Industrials)
# ✅ บันทึก CBG สำเร็จ! (Sector: Consumer Defensive)
# ✅ บันทึก CPALL สำเร็จ! (Sector: Consumer Defensive)
# ✅ บันทึก CPF สำเร็จ! (Sector: Consumer Defensive)
# ✅ บันทึก CPN สำเร็จ! (Sector: Real Estate)
# ✅ บันทึก CRC สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก DELTA สำเร็จ! (Sector: Industrials)
# ✅ บันทึก EA สำเร็จ! (Sector: Utilities)
# ✅ บันทึก EGCO สำเร็จ! (Sector: Utilities)
# ✅ บันทึก GLOBAL สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก GPSC สำเร็จ! (Sector: Utilities)
# ✅ บันทึก GULF สำเร็จ! (Sector: Utilities)
# ✅ บันทึก HMPRO สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก IVL สำเร็จ! (Sector: Basic Materials)
# ✅ บันทึก KBANK สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก KTB สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก KTC สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก LH สำเร็จ! (Sector: Real Estate)
# ✅ บันทึก MINT สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก MTC สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก OR สำเร็จ! (Sector: Energy)
# ✅ บันทึก OSP สำเร็จ! (Sector: Consumer Defensive)
# ✅ บันทึก PTT สำเร็จ! (Sector: Energy)
# ✅ บันทึก PTTEP สำเร็จ! (Sector: Energy)
# ✅ บันทึก PTTGC สำเร็จ! (Sector: Basic Materials)
# ✅ บันทึก RATCH สำเร็จ! (Sector: Utilities)
# ✅ บันทึก SAWAD สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก SCB สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก SCC สำเร็จ! (Sector: Industrials)
# ✅ บันทึก SCGP สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก TISCO สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก TOP สำเร็จ! (Sector: Energy)
# ✅ บันทึก TRUE สำเร็จ! (Sector: Communication Services)
# ✅ บันทึก TTB สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก TU สำเร็จ! (Sector: Consumer Defensive)
# ✅ บันทึก WHA สำเร็จ! (Sector: Real Estate)
# ✅ บันทึก AMATA สำเร็จ! (Sector: Real Estate)
# ✅ บันทึก AP สำเร็จ! (Sector: Real Estate)
# ✅ บันทึก AWC สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก BAM สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก BANPU สำเร็จ! (Sector: Energy)
# ✅ บันทึก BCH สำเร็จ! (Sector: Healthcare)
# ✅ บันทึก BCP สำเร็จ! (Sector: Energy)
# ✅ บันทึก BCPG สำเร็จ! (Sector: Utilities)
# ✅ บันทึก BLA สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก BPP สำเร็จ! (Sector: Utilities)
# ✅ บันทึก CENTEL สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก CHG สำเร็จ! (Sector: Healthcare)
# ✅ บันทึก CK สำเร็จ! (Sector: Industrials)
# ✅ บันทึก CKP สำเร็จ! (Sector: Utilities)
# ✅ บันทึก COM7 สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก DOHOME สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก EPG สำเร็จ! (Sector: Basic Materials)
# ✅ บันทึก ERW สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก FORTH สำเร็จ! (Sector: Industrials)
# ✅ บันทึก HANA สำเร็จ! (Sector: Technology)
# ✅ บันทึก ICHI สำเร็จ! (Sector: Consumer Defensive)
# ✅ บันทึก ILM สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก JAS สำเร็จ! (Sector: Communication Services)
# ✅ บันทึก JMART สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก JMT สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก KCE สำเร็จ! (Sector: Technology)
# ✅ บันทึก KKP สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก MEGA สำเร็จ! (Sector: Healthcare)
# ✅ บันทึก ONEE สำเร็จ! (Sector: Communication Services)
# ✅ บันทึก ORI สำเร็จ! (Sector: Real Estate)
# ✅ บันทึก PLANB สำเร็จ! (Sector: Communication Services)
# ✅ บันทึก PSL สำเร็จ! (Sector: Industrials)
# ✅ บันทึก PTG สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก QH สำเร็จ! (Sector: Real Estate)
# ✅ บันทึก RBF สำเร็จ! (Sector: Consumer Defensive)
# ✅ บันทึก RCL สำเร็จ! (Sector: Industrials)
# ✅ บันทึก RS สำเร็จ! (Sector: Communication Services)
# ✅ บันทึก SABINA สำเร็จ! (Sector: Consumer Cyclical)
# ✅ บันทึก SINGER สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก SIRI สำเร็จ! (Sector: Real Estate)
# ✅ บันทึก SPALI สำเร็จ! (Sector: Real Estate)
# ✅ บันทึก SPRC สำเร็จ! (Sector: Energy)
# ✅ บันทึก STA สำเร็จ! (Sector: Basic Materials)
# ✅ บันทึก STGT สำเร็จ! (Sector: Basic Materials)
# ✅ บันทึก SUPER สำเร็จ! (Sector: Utilities)
# ✅ บันทึก SYNEX สำเร็จ! (Sector: Technology)
# ✅ บันทึก TASCO สำเร็จ! (Sector: Basic Materials)
# ✅ บันทึก TCAP สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก THANI สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก THCOM สำเร็จ! (Sector: Technology)
# ✅ บันทึก THG สำเร็จ! (Sector: Healthcare)
# ✅ บันทึก TIDLOR สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก TIPH สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก TKN สำเร็จ! (Sector: Consumer Defensive)
# ✅ บันทึก TQM สำเร็จ! (Sector: Financial Services)
# ✅ บันทึก TTA สำเร็จ! (Sector: Industrials)
# ✅ บันทึก VGI สำเร็จ! (Sector: Industrials)
# ✅ บันทึก WICE สำเร็จ! (Sector: Industrials)
# ✅ บันทึก XPG สำเร็จ! (Sector: Financial Services)
#
# 🎉 สำเร็จแล้ว! ดึงข้อมูลและบันทึกลง Database ได้ทั้งหมด 102 ตัว!

# %%
kbank = yf.Ticker("KBANK.BK")

# %%
kbank.info
# Out:
# {'address1': '400/22 Phahon Yothin Road',
#  'address2': 'Sam Sen Nai Sub-District Phaya Thai District',
#  'city': 'Bangkok',
#  'zip': '10400',
#  'country': 'Thailand',
#  'phone': '66 2 222 0000',
#  'fax': '66 2 470 1144',
#  'website': 'https://www.kasikornbank.com',
#  'industry': 'Banks - Regional',
#  'industryKey': 'banks-regional',
#  'industryDisp': 'Banks - Regional',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
#  'longBusinessSummary': 'Kasikornbank Public Company Limited provides commercial banking products and services in Thailand and internationally. Its personal banking products and services include savings, e-savings, current, fixed deposit, and foreign currency deposit accounts; personal, home, and auto loans; debit and credit cards; health, life, accident, travel, saving, retirement, and non-life insurance products; investment products, such as mutual funds, stocks, debentures/bonds, derivatives/futures exchange, and Wealth PLUS services; money transfer and bill payment, cheque and draft, and foreign exchange services; and digital banking services. The company also offers various products and services for business customers, such as current, savings, special savings deposit, and fixed deposit accounts, as well as collection, payment, liquidity management, and online merchant solutions; international trade solutions comprising import and export service, global money transfer, guarantee, and trade finance solutions; long term loans, working capital loans, commercial loans, letters of guarantee, and K-Aval PN/K-Acceptance B/E services; life, non-life, and group insurance products; business card services; and electronic service solutions, cash management solutions, foreign exchange and derivatives, corporate finance, securities, and investment, as well as syndicated loans and value chain solutions. In addition, it provides auto and equipment leasing, venture capital management, lending, asset management, fund management, insurance broker, and digital asset fund manager services, as well as invests in other companies. Further, the company offers stockbroker, green solutions, property sale, electric vehicle, payment, and battery swap services, as well as honeycomb papers. Additionally, it provides information and communication system development; and professional conference organizing services. The company was founded in 1945 and is headquartered in Bangkok, Thailand.',
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Ms. Kattiya  Indaravijaya',
#    'age': 60,
#    'title': 'CEO & Executive Director',
#    'yearBorn': 1965,
#    'fiscalYear': 2024,
#    'totalPay': 6526979,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Pipatpong  Poshyanonda',
#    'age': 56,
#    'title': 'President',
#    'yearBorn': 1969,
#    'fiscalYear': 2024,
#    'totalPay': 4888215,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chongrak  Rattanapian',
#    'age': 56,
#    'title': 'President',
#    'yearBorn': 1969,
#    'fiscalYear': 2024,
#    'totalPay': 2888462,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Rungruang  Sukkirdkijpiboon',
#    'age': 54,
#    'title': 'President',
#    'yearBorn': 1971,
#    'fiscalYear': 2024,
#    'totalPay': 2194740,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Pipit  Aneaknithi',
#    'age': 58,
#    'title': 'Chairman of Global Sustainability',
#    'yearBorn': 1967,
#    'fiscalYear': 2024,
#    'totalPay': 4888215,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Chonchanum  Soonthornsaratoon',
#    'age': 56,
#    'title': 'Legal Adviser & Non-Executive Director',
#    'yearBorn': 1969,
#    'fiscalYear': 2024,
#    'totalPay': 11110979,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Krit  Jitjang',
#    'age': 53,
#    'title': 'Company Secretary',
#    'yearBorn': 1972,
#    'fiscalYear': 2024,
#    'totalPay': 1999753,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Nathapol  Luepromchai',
#    'title': 'Executive Vice President',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Sansana  Sukhanunth',
#    'age': 55,
#    'title': 'Executive VP, CFO & Chief Accounting',
#    'yearBorn': 1970,
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Pornvipa  Tangtrongchit',
#    'title': 'Head of Investment Banking Business',
#    'fiscalYear': 2024,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'compensationAsOfEpochDate': 1735603200,
#  'irWebsite': 'http://www.kasikornbank.com/EN/Investors/Pages/Investors.aspx',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 196.5,
#  'open': 197.0,
#  'dayLow': 196.5,
#  'dayHigh': 200.0,
#  'regularMarketPreviousClose': 196.5,
#  'regularMarketOpen': 197.0,
#  'regularMarketDayLow': 196.5,
#  'regularMarketDayHigh': 200.0,
#  'dividendRate': 10.0,
#  'dividendYield': 5.09,
#  'exDividendDate': 1757462400,
#  'payoutRatio': 0.49,
#  'fiveYearAvgDividendYield': 3.53,
#  'beta': 0.168,
#  'trailingPE': 9.745348,
#  'forwardPE': 9.715207,
#  'volume': 15946505,
#  'regularMarketVolume': 15946505,
#  'averageVolume': 13181231,
#  'averageVolume10days': 24793550,
#  'averageDailyVolume10Day': 24793550,
#  'bid': 0.0,
#  'ask': 0.0,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 471496196096,
#  'fiftyTwoWeekLow': 145.0,
#  'fiftyTwoWeekHigh': 208.0,
#  'allTimeHigh': 252.0,
#  'allTimeLow': 13.75,
#  'priceToSalesTrailing12Months': 3.0519853,
#  'fiftyDayAverage': 193.36,
#  'twoHundredDayAverage': 174.24,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'THB',
#  'tradeable': False,
#  'enterpriseValue': 142393425920,
#  'profitMargins': 0.32083,
#  'floatShares': 2048899729,
#  'sharesOutstanding': 2369327593,
#  'heldPercentInsiders': 0.15144,
#  'heldPercentInstitutions': 0.21540001,
#  'impliedSharesOutstanding': 2369327594,
#  'bookValue': 245.279,
#  'priceToBook': 0.81132096,
#  'lastFiscalYearEnd': 1767139200,
#  'nextFiscalYearEnd': 1798675200,
#  'mostRecentQuarter': 1767139200,
#  'earningsQuarterlyGrowth': -0.021,
#  'netIncomeToCommon': 49564770304,
#  'trailingEps': 20.42,
#  'forwardEps': 20.48335,
#  'enterpriseToRevenue': 0.922,
#  '52WeekChange': 0.30158734,
#  'SandP52WeekChange': 0.15480888,
#  'lastDividendValue': 2.0,
#  'lastDividendDate': 1757462400,
#  'quoteType': 'EQUITY',
#  'currentPrice': 199.0,
#  'targetHighPrice': 225.0,
#  'targetLowPrice': 170.0,
#  'targetMeanPrice': 195.51053,
#  'targetMedianPrice': 195.0,
#  'recommendationMean': 2.57895,
#  'recommendationKey': 'hold',
#  'numberOfAnalystOpinions': 19,
#  'totalCash': 726505881600,
#  'totalCashPerShare': 306.63,
#  'totalDebt': 310704668672,
#  'totalRevenue': 154488356864,
#  'revenuePerShare': 65.227,
#  'returnOnAssets': 0.01255,
#  'returnOnEquity': 0.085439995,
#  'grossProfits': 154488356864,
#  'earningsGrowth': -0.019,
#  'revenueGrowth': 0.031,
#  'grossMargins': 0.0,
#  'ebitdaMargins': 0.0,
#  'operatingMargins': 0.38735,
#  'financialCurrency': 'THB',
#  'symbol': 'KBANK.BK',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'LOW',
#  'fiftyTwoWeekRange': '145.0 - 208.0',
#  'fiftyTwoWeekHighChange': -9.0,
#  'fiftyTwoWeekHighChangePercent': -0.043269232,
#  'fiftyTwoWeekChangePercent': 30.158733,
#  'earningsTimestamp': 1776763800,
#  'earningsTimestampStart': 1776763800,
#  'earningsTimestampEnd': 1776763800,
#  'earningsCallTimestampStart': 1761044340,
#  'earningsCallTimestampEnd': 1761044340,
#  'isEarningsDateEstimate': False,
#  'epsTrailingTwelveMonths': 20.42,
#  'epsForward': 20.48335,
#  'epsCurrentYear': 19.57071,
#  'priceEpsCurrentYear': 10.168257,
#  'fiftyDayAverageChange': 5.6399994,
#  'fiftyDayAverageChangePercent': 0.029168388,
#  'twoHundredDayAverageChange': 24.759995,
#  'twoHundredDayAverageChangePercent': 0.14210281,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 15,
#  'averageAnalystRating': '2.6 - Hold',
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 946954800000,
#  'regularMarketChange': 2.5,
#  'regularMarketDayRange': '196.5 - 200.0',
#  'fullExchangeName': 'Thailand',
#  'averageDailyVolume3Month': 13181231,
#  'fiftyTwoWeekLowChange': 54.0,
#  'fiftyTwoWeekLowChangePercent': 0.37241378,
#  'shortName': 'KBANK_KASIKORNBANK',
#  'exchange': 'SET',
#  'messageBoardId': 'finmb_874661',
#  'exchangeTimezoneName': 'Asia/Bangkok',
#  'exchangeTimezoneShortName': 'ICT',
#  'gmtOffSetMilliseconds': 25200000,
#  'market': 'th_market',
#  'esgPopulated': False,
#  'marketState': 'REGULAR',
#  'corporateActions': [],
#  'regularMarketTime': 1772083799,
#  'longName': 'Kasikornbank Public Company Limited',
#  'regularMarketChangePercent': 1.2722646,
#  'regularMarketPrice': 199.0,
#  'trailingPegRatio': 1.0152}

# %%
kbank.history(period = '1y')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-02-26 00:00:00+07:00  142.579451  144.886561  137.965229  138.426651
# 2025-02-27 00:00:00+07:00  137.042365  142.118008  136.119521  139.810898
# 2025-02-28 00:00:00+07:00  138.888054  139.810898  137.042365  139.810898
# 2025-03-03 00:00:00+07:00  140.733749  142.118016  139.810905  140.733749
# 2025-03-04 00:00:00+07:00  140.733749  141.656594  138.426639  140.733749
# ...                               ...         ...         ...         ...
# 2026-02-20 00:00:00+07:00  205.000000  206.000000  202.000000  205.000000
# 2026-02-23 00:00:00+07:00  204.000000  206.000000  199.500000  201.000000
# 2026-02-24 00:00:00+07:00  202.000000  202.000000  198.000000  201.000000
# 2026-02-25 00:00:00+07:00  200.000000  201.000000  194.500000  196.500000
# 2026-02-26 00:00:00+07:00  197.000000  200.000000  196.500000  199.000000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-02-26 00:00:00+07:00  19549200        0.0           0.0
# 2025-02-27 00:00:00+07:00  14083700        0.0           0.0
# 2025-02-28 00:00:00+07:00  14197400        0.0           0.0
# 2025-03-03 00:00:00+07:00  10293600        0.0           0.0
# 2025-03-04 00:00:00+07:00   8198900        0.0           0.0
# ...                             ...        ...           ...
# 2026-02-20 00:00:00+07:00  28943000        0.0           0.0
# 2026-02-23 00:00:00+07:00  20454700        0.0           0.0
# 2026-02-24 00:00:00+07:00  26551400        0.0           0.0
# 2026-02-25 00:00:00+07:00  47259100        0.0           0.0
# 2026-02-26 00:00:00+07:00  15946505        0.0           0.0
#
# [243 rows x 7 columns]

# %%
kbank.history(period = '1y')["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
kbank.calendar
# Out:
# {'Ex-Dividend Date': datetime.date(2025, 9, 10),
#  'Earnings Date': [datetime.date(2026, 4, 21)],
#  'Earnings High': 5.69,
#  'Earnings Low': 4.97609,
#  'Earnings Average': 5.33304,
#  'Revenue High': 47996896000,
#  'Revenue Low': 47996896000,
#  'Revenue Average': 47996896000}

# %%
kbank.quarterly_income_stmt
# Out:
#                                                       2025-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.990640e-01
# Total Unusual Items                                          NaN
# Total Unusual Items Excluding Goodwill                       NaN
# Net Income From Continuing Operation Net Minori...  1.300719e+10
# Reconciled Depreciation                             2.425158e+09
# Net Interest Income                                 3.415815e+10
# Interest Expense                                    8.901204e+09
# Interest Income                                     4.305935e+10
# Normalized Income                                   1.300719e+10
# Net Income From Continuing And Discontinued Ope...  1.300719e+10
# Diluted Average Shares                              2.369328e+09
# Basic Average Shares                                2.369328e+09
# Diluted EPS                                         5.350000e+00
# Basic EPS                                           5.350000e+00
# Diluted NI Availto Com Stockholders                 1.300719e+10
# Net Income Common Stockholders                      1.300719e+10
# Net Income                                          1.300719e+10
# Minority Interests                                 -1.490543e+09
# Net Income Including Noncontrolling Interests       1.449773e+10
# Net Income Continuous Operations                    1.449773e+10
# Tax Provision                                       3.603253e+09
# Pretax Income                                       1.810099e+10
# Special Income Charges                                       NaN
# Gain On Sale Of Business                                     NaN
# Gain On Sale Of Security                            4.675335e+09
# Selling General And Administration                  1.125233e+10
# General And Administrative Expense                  1.125233e+10
# Insurance And Claims                                         NaN
# Salaries And Wages                                  1.125233e+10
# Total Revenue                                       4.897944e+10
# Operating Revenue                                   4.897944e+10
# Occupancy And Equipment                             2.899668e+09
# Other Non Interest Expense                          6.813209e+09
#
#                                                       2025-06-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.962000e-01
# Total Unusual Items                                          NaN
# Total Unusual Items Excluding Goodwill                       NaN
# Net Income From Continuing Operation Net Minori...  1.248819e+10
# Reconciled Depreciation                             2.347252e+09
# Net Interest Income                                 3.776700e+10
# Interest Expense                                    6.171000e+09
# Interest Income                                     4.393800e+10
# Normalized Income                                   1.248819e+10
# Net Income From Continuing And Discontinued Ope...  1.248819e+10
# Diluted Average Shares                              2.369328e+09
# Basic Average Shares                                2.369328e+09
# Diluted EPS                                         5.270000e+00
# Basic EPS                                           5.270000e+00
# Diluted NI Availto Com Stockholders                 1.248819e+10
# Net Income Common Stockholders                      1.248819e+10
# Net Income                                          1.248819e+10
# Minority Interests                                 -1.775842e+09
# Net Income Including Noncontrolling Interests       1.426403e+10
# Net Income Continuous Operations                    1.426403e+10
# Tax Provision                                       3.482385e+09
# Pretax Income                                       1.774642e+10
# Special Income Charges                                       NaN
# Gain On Sale Of Business                                     NaN
# Gain On Sale Of Security                            1.353000e+09
# Selling General And Administration                  1.358494e+10
# General And Administrative Expense                  1.358494e+10
# Insurance And Claims                                3.112000e+09
# Salaries And Wages                                  1.047294e+10
# Total Revenue                                       5.187028e+10
# Operating Revenue                                   5.187028e+10
# Occupancy And Equipment                             2.750848e+09
# Other Non Interest Expense                          7.579796e+09
#
#                                                       2025-03-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  2.067590e-01
# Total Unusual Items                                          NaN
# Total Unusual Items Excluding Goodwill                       NaN
# Net Income From Continuing Operation Net Minori...  1.379145e+10
# Reconciled Depreciation                             2.323653e+09
# Net Interest Income                                 3.542541e+10
# Interest Expense                                    9.537302e+09
# Interest Income                                     4.496272e+10
# Normalized Income                                   1.379145e+10
# Net Income From Continuing And Discontinued Ope...  1.379145e+10
# Diluted Average Shares                              2.369328e+09
# Basic Average Shares                                2.369328e+09
# Diluted EPS                                         5.670000e+00
# Basic EPS                                           5.670000e+00
# Diluted NI Availto Com Stockholders                 1.379145e+10
# Net Income Common Stockholders                      1.379145e+10
# Net Income                                          1.379145e+10
# Minority Interests                                 -1.464669e+09
# Net Income Including Noncontrolling Interests       1.525612e+10
# Net Income Continuous Operations                    1.525612e+10
# Tax Provision                                       3.976533e+09
# Pretax Income                                       1.923265e+10
# Special Income Charges                                       NaN
# Gain On Sale Of Business                                     NaN
# Gain On Sale Of Security                            4.360815e+09
# Selling General And Administration                  1.056800e+10
# General And Administrative Expense                  1.056800e+10
# Insurance And Claims                                         NaN
# Salaries And Wages                                  1.056800e+10
# Total Revenue                                       4.892708e+10
# Operating Revenue                                   4.892708e+10
# Occupancy And Equipment                             2.781956e+09
# Other Non Interest Expense                          6.701932e+09
#
#                                                       2024-12-31  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.938100e-01
# Total Unusual Items                                          NaN
# Total Unusual Items Excluding Goodwill                       NaN
# Net Income From Continuing Operation Net Minori...  1.049406e+10
# Reconciled Depreciation                             2.344136e+09
# Net Interest Income                                 4.864645e+10
# Interest Expense                                   -2.487204e+09
# Interest Income                                     4.615924e+10
# Normalized Income                                   1.049406e+10
# Net Income From Continuing And Discontinued Ope...  1.049406e+10
# Diluted Average Shares                                       NaN
# Basic Average Shares                                         NaN
# Diluted EPS                                                  NaN
# Basic EPS                                                    NaN
# Diluted NI Availto Com Stockholders                 1.049406e+10
# Net Income Common Stockholders                      1.049406e+10
# Net Income                                          1.049406e+10
# Minority Interests                                 -2.052630e+08
# Net Income Including Noncontrolling Interests       1.069932e+10
# Net Income Continuous Operations                    1.069932e+10
# Tax Provision                                       2.572138e+09
# Pretax Income                                       1.327146e+10
# Special Income Charges                                       NaN
# Gain On Sale Of Business                                     NaN
# Gain On Sale Of Security                           -6.398718e+09
# Selling General And Administration                  2.355763e+10
# General And Administrative Expense                  2.355763e+10
# Insurance And Claims                                         NaN
# Salaries And Wages                                  1.125563e+10
# Total Revenue                                       6.061916e+10
# Operating Revenue                                   6.061916e+10
# Occupancy And Equipment                             3.045497e+09
# Other Non Interest Expense                          8.870595e+09
#
#                                                       2024-09-30    2024-06-30
# Tax Effect Of Unusual Items                         0.000000e+00           NaN
# Tax Rate For Calcs                                  2.063110e-01           NaN
# Total Unusual Items                                          NaN  0.000000e+00
# Total Unusual Items Excluding Goodwill                       NaN  0.000000e+00
# Net Income From Continuing Operation Net Minori...  1.229533e+10           NaN
# Trading Securities                                     NaN           NaN
# Long Term Equity Investment                   1.340385e+10  1.307098e+10
# Goodwill And Other Intangible Assets          3.144051e+10  3.046921e+10
# Other Intangible Assets                                NaN  2.477621e+10
# Goodwill                                               NaN  5.693000e+09
# Net PPE                                       6.133143e+10  5.943100e+10
# Accumulated Depreciation                               NaN -4.963600e+10
# Gross PPE                                              NaN  1.090670e+11
# Other Properties                                       NaN  4.069700e+10
# Buildings And Improvements                             NaN  4.209500e+10
# Land And Improvements                                  NaN  2.627500e+10
# Receivables                                            NaN  7.860310e+11
# Other Receivables                                      NaN  1.495830e+11
# Notes Receivable                                       NaN  6.183690e+11
# Accounts Receivable                                    NaN  1.807900e+10
# Other Short Term Investments                  9.873600e+11  4.220630e+11
# Cash And Cash Equivalents                     3.772795e+10  3.566794e+11
# Cash Financial                                3.772795e+10  4.602138e+10
# Cash Cash Equivalents And Federal Funds Sold  3.772795e+10  3.566794e+11
#
#                                                 2024-09-30    2024-06-30
# Ordinary Shares Number                        2.369328e+09           NaN
# Share Issued                                  2.369328e+09           NaN
# Net Debt                                      1.801077e+11           NaN
# Total Debt                                    2.134231e+11           NaN
# Tangible Book Value                           5.216235e+11           NaN
# Invested Capital                              7.645424e+11           NaN
# Net Tangible Assets                           5.216235e+11           NaN
# Common Stock Equity                           5.511193e+11           NaN
# Total Capitalization                          7.645424e+11           NaN
# Total Equity Gross Minority Interest          6.187332e+11           NaN
# Minority Interest                             6.761394e+10           NaN
# Stockholders Equity                           5.511193e+11           NaN
# Other Equity Interest                         1.554917e+10           NaN
# Gains Losses Not Affecting Retained Earnings  1.996482e+10           NaN
# Other Equity Adjustments                      1.996482e+10           NaN
# Retained Earnings                             4.738089e+11           NaN
# Additional Paid In Capital                    1.810311e+10           NaN
# Capital Stock                                 2.369328e+10           NaN
# Common Stock                                  2.369328e+10           NaN
# Total Liabilities Net Minority Interest       3.748292e+12           NaN
# Derivative Product Liabilities                6.548249e+10           NaN
# Non Current Deferred Liabilities              5.591260e+08           NaN
# Non Current Deferred Taxes Liabilities        5.591260e+08           NaN
# Long Term Debt And Capital Lease Obligation   2.134231e+11           NaN
# Long Term Debt                                2.134231e+11           NaN
# Long Term Provisions                          3.754676e+10           NaN
# Payables And Accrued Expenses                 3.231704e+10           NaN
# Payables                                      3.231704e+10           NaN
# Other Payable                                 3.231704e+10           NaN
# Total Assets                                  4.367025e+12           NaN
# Investments And Advances                      1.033027e+12           NaN
# Available For Sale Securities                 6.539120e+11           NaN
# Trading Securities                                     NaN           NaN
# Long Term Equity Investment                   1.245017e+10           NaN
# Goodwill And Other Intangible Assets          2.949583e+10           NaN
# Other Intangible Assets                                NaN  2.355234e+10
# Goodwill                                               NaN  5.693000e+09
# Net PPE                                       5.868671e+10           NaN
# Accumulated Depreciation                               NaN -4.941400e+10
# Gross PPE                                              NaN  1.087370e+11
# Other Properties                                       NaN  4.078700e+10
# Buildings And Improvements                             NaN  4.159200e+10
# Land And Improvements                                  NaN  2.635800e+10
# Change In Other Current Liabilities            -1.727542e+10 -5.524184e+09
# Change In Other Current Assets                  2.334645e+09  1.174294e+10
# Change In Payables And Accrued Expense                   NaN           NaN
# Change In Accrued Expense                                NaN           NaN
# Other Non Cash Items                           -3.556195e+10 -3.694483e+10
# Asset Impairment Charge                         3.352300e+07 -5.107700e+07
# Depreciation Amortization Depletion             2.323653e+09  2.344136e+09
# Depreciation And Amortization                   2.323653e+09  2.344136e+09
# Operating Gains Losses                         -2.026357e+09  1.666583e+09
# Earnings Losses From Equity Investments        -1.756480e+08 -2.692700e+08
# Gain Loss On Investment Securities             -2.104580e+08 -4.866700e+07
# Net Foreign Currency Exchange Gain Loss         2.208600e+07  5.255500e+08
# Gain Loss On Sale Of PPE                       -8.760000e+06  7.975000e+06
# Gain Loss On Sale Of Business                   0.000000e+00  2.218000e+06
# Net Income From Continuing Operations           1.923265e+10  1.327146e+10
#
#                                                   2024-09-30   2024-06-30
# Free Cash Flow                                 -2.855793e+10          NaN
# Repayment Of Debt                              -3.169340e+08          NaN
# Issuance Of Debt                                0.000000e+00  -78827000.0
# Capital Expenditure                            -2.003174e+09          NaN
# End Cash Position                               3.331541e+10          NaN
# Beginning Cash Position                         3.026458e+10          NaN
# Effect Of Exchange Rate Changes                -1.574160e+08          NaN
# Changes In Cash                                 3.208251e+09          NaN
# Financing Cash Flow                            -3.870925e+09          NaN
# Cash Flow From Continuing Financing Activities -3.870925e+09          NaN
# Net Other Financing Charges                     0.000000e+00          NaN
# Cash Dividends Paid                            -3.553991e+09          NaN
# Common Stock Dividend Paid                     -3.553991e+09          NaN
# Net Issuance Payments Of Debt                  -3.169340e+08          NaN
# Net Long Term Debt Issuance                    -3.169340e+08          NaN
# Long Term Debt Payments                        -3.169340e+08          NaN
# Long Term Debt Issuance                         0.000000e+00  -78827000.0
# Investing Cash Flow                             3.363393e+10          NaN
# Cash Flow From Continuing Investing Activities  3.363393e+10          NaN
# Net Investment Purchase And Sale                3.663403e+10          NaN
# Sale Of Investment                              1.008396e+11          NaN
# Purchase Of Investment                         -6.420553e+10          NaN
# Net Business Purchase And Sale                 -1.038600e+09          NaN
# Sale Of Business                                0.000000e+00          NaN
# Purchase Of Business                           -1.038600e+09          NaN
# Net Intangibles Purchase And Sale              -1.313605e+09          NaN
# Sale Of Intangibles                             3.447400e+07          NaN
# Purchase Of Intangibles                        -1.348079e+09          NaN
# Net PPE Purchase And Sale                      -6.478940e+08          NaN
# Sale Of PPE                                     7.201000e+06          NaN
# Purchase Of PPE                                -6.550950e+08          NaN
# Operating Cash Flow                            -2.655476e+10          NaN
# Cash Flow From Continuing Operating Activities -2.655476e+10          NaN
# Taxes Refund Paid                              -5.669746e+09          NaN
# Interest Received Cfo                           4.103621e+10          NaN
# Interest Paid Cfo                              -1.160701e+10          NaN
# Dividend Received Cfo                           1.195486e+09          NaN
# Change In Working Capital                      -4.089888e+10          NaN
# Change In Other Working Capital                 9.647544e+10          NaN
# Change In Other Current Liabilities             3.509558e+10          NaN
# Change In Other Current Assets                  6.848532e+09          NaN
# Change In Payables And Accrued Expense                   NaN  507707000.0
# Change In Accrued Expense                                NaN  507707000.0
# Other Non Cash Items                           -3.668719e+10          NaN
# Asset Impairment Charge                         1.168780e+08          NaN
# Depreciation Amortization Depletion             2.186675e+09          NaN
# Depreciation And Amortization                   2.186675e+09          NaN
# Operating Gains Losses                         -3.295679e+09          NaN
# Earnings Losses From Equity Investments        -2.881440e+08          NaN
# Gain Loss On Investment Securities             -6.914500e+07          NaN
# Net Foreign Currency Exchange Gain Loss        -1.579192e+09          NaN
# Gain Loss On Sale Of PPE                       -7.511000e+06          NaN
# Gain Loss On Sale Of Business                  -1.000000e+03          NaN
# Net Income From Continuing Operations           1.661360e+10          NaN

# %%
import yfinance as yf
import psycopg2
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')

# 1. เชื่อมต่อ Database
conn = psycopg2.connect(host="127.0.0.1", database="thai_stocks_db", user="postgres", password="Shifa.326459")
conn.autocommit = True
cur = conn.cursor()

print("🔧 กำลังสร้างตารางใหม่สำหรับข้อมูลพื้นฐานและงบการเงิน...")

# 2. สร้างตาราง company_profiles
cur.execute("""
CREATE TABLE IF NOT EXISTS company_profiles (
    symbol VARCHAR(20) PRIMARY KEY REFERENCES stocks(symbol),
    company_name VARCHAR(255),
    industry VARCHAR(100),
    website VARCHAR(255),
    trailing_pe NUMERIC,
    dividend_yield NUMERIC,
    next_earnings_date DATE
);
""")

# 3. สร้างตาราง quarterly_financials
cur.execute("""
CREATE TABLE IF NOT EXISTS quarterly_financials (
    symbol VARCHAR(20) REFERENCES stocks(symbol),
    quarter_end_date DATE,
    total_revenue NUMERIC,
    gross_profit NUMERIC,
    net_income NUMERIC,
    PRIMARY KEY (symbol, quarter_end_date)
);
""")
print("✅ สร้างตารางสำเร็จ!")

# 4. ดึงรายชื่อหุ้นจาก Database มาอัปเดตข้อมูล
cur.execute("SELECT symbol FROM stocks;")
symbols = [row[0] for row in cur.fetchall()]

# ตัดให้เหลือ 10 ตัวแรกก่อนเพื่อความรวดเร็วในการเทสต์ระบบ (ถ้าอยากดึงหมดให้ลบ [:10] ออกครับ)
test_symbols = symbols[:10] 

print(f"⏳ เริ่มโหลดข้อมูล Profile & Financials สำหรับหุ้น {len(test_symbols)} ตัว...")

success_count = 0

for sym in test_symbols:
    try:
        ticker = yf.Ticker(f"{sym}.BK")
        
        # -----------------------------------------
        # ส่วนที่ 1: ดึงข้อมูลจาก .info และ .calendar
        # -----------------------------------------
        info = ticker.info
        
        comp_name = info.get('longName', '')
        industry = info.get('industry', '')
        website = info.get('website', '')
        pe = info.get('trailingPE', None)
        div_yield = info.get('dividendYield', None)
        
        # แปลง Yield ให้เป็น % (ถ้ามีค่า)
        if div_yield is not None:
            div_yield = div_yield * 100
            
        # ดึงวันที่ประกาศงบครั้งถัดไปจาก calendar
        # yfinance บางเวอร์ชัน calendar จะมาเป็น dict
        cal = ticker.calendar
        next_earn_date = None
        if isinstance(cal, dict) and 'Earnings Date' in cal:
            next_earn_date = cal['Earnings Date'][0] if len(cal['Earnings Date']) > 0 else None

        # UPSERT ลง company_profiles
        cur.execute("""
            INSERT INTO company_profiles (symbol, company_name, industry, website, trailing_pe, dividend_yield, next_earnings_date)
            VALUES (%s, %s, %s, %s, %s, %s, %s)
            ON CONFLICT (symbol) DO UPDATE 
            SET company_name = EXCLUDED.company_name, industry = EXCLUDED.industry, 
                trailing_pe = EXCLUDED.trailing_pe, dividend_yield = EXCLUDED.dividend_yield;
        """, (sym, comp_name, industry, website, pe, div_yield, next_earn_date))

        # -----------------------------------------
        # ส่วนที่ 2: ดึงข้อมูลงบจาก .quarterly_income_stmt
        # -----------------------------------------
        q_income = ticker.quarterly_income_stmt
        
        if not q_income.empty:
            # yfinance จะคืนค่ามาโดยให้ "วันที่" เป็นคอลัมน์ และ "รายการบัญชี" เป็น index (แถว)
            # เราต้องลูปตามคอลัมน์ (วันที่)
            for date_col in q_income.columns:
                q_date = date_col.date()
                
                # ดึงข้อมูลแต่ละรายการ (ใช้ .get ป้องกัน error ถ้าไม่มีบรรทัดนั้น)
                tot_rev = q_income[date_col].get('Total Revenue', 0)
                gross_p = q_income[date_col].get('Gross Profit', 0)
                net_inc = q_income[date_col].get('Net Income', 0)
                
                # แปลงค่า NaN เป็น 0 หรือ None เพื่อให้ SQL ไม่พัง
                tot_rev = float(tot_rev) if pd.notna(tot_rev) else 0
                gross_p = float(gross_p) if pd.notna(gross_p) else 0
                net_inc = float(net_inc) if pd.notna(net_inc) else 0

                # UPSERT ลง quarterly_financials
                cur.execute("""
                    INSERT INTO quarterly_financials (symbol, quarter_end_date, total_revenue, gross_profit, net_income)
                    VALUES (%s, %s, %s, %s, %s)
                    ON CONFLICT (symbol, quarter_end_date) DO UPDATE 
                    SET total_revenue = EXCLUDED.total_revenue, gross_profit = EXCLUDED.gross_profit, net_income = EXCLUDED.net_income;
                """, (sym, q_date, tot_rev, gross_p, net_inc))
        
        print(f"✅ ดึงข้อมูล {sym} สำเร็จ")
        success_count += 1
        time.sleep(0.5) # พักเซิร์ฟเวอร์
        
    except Exception as e:
        print(f"⚠️ ข้าม {sym}: {e}")

print(f"\n🎉 อัปเดตข้อมูลทั่วไปและงบการเงินสำเร็จ {success_count} ตัว!")

conn.close()
# Out:
# 🔧 กำลังสร้างตารางใหม่สำหรับข้อมูลพื้นฐานและงบการเงิน...
# ✅ สร้างตารางสำเร็จ!
# ⏳ เริ่มโหลดข้อมูล Profile & Financials สำหรับหุ้น 10 ตัว...
# ✅ ดึงข้อมูล ADVANC สำเร็จ
# ✅ ดึงข้อมูล AOT สำเร็จ
# ✅ ดึงข้อมูล BBL สำเร็จ
# ✅ ดึงข้อมูล BDMS สำเร็จ
# ✅ ดึงข้อมูล BEM สำเร็จ
# ✅ ดึงข้อมูล BGRIM สำเร็จ
# ✅ ดึงข้อมูล BH สำเร็จ
# ✅ ดึงข้อมูล BTS สำเร็จ
# ✅ ดึงข้อมูล CBG สำเร็จ
# ✅ ดึงข้อมูล CPALL สำเร็จ
#
# 🎉 อัปเดตข้อมูลทั่วไปและงบการเงินสำเร็จ 10 ตัว!

# %%
import psycopg2
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from IPython.display import display, Markdown
import warnings
warnings.filterwarnings('ignore')

def print_topic(text):
    display(Markdown(f"### 🎯 {text}"))

# ==========================================
# 1. ดึงข้อมูลจาก Database
# ==========================================
conn = psycopg2.connect(host="127.0.0.1", database="thai_stocks_db", user="postgres", password="Shifa.326459")
cur = conn.cursor()

# ดึงชื่อหุ้นและ Market Cap ออกมาเพื่อใช้ถ่วงน้ำหนัก (Weighting)
df_stocks = pd.read_sql("SELECT symbol, market_cap FROM stocks WHERE market_cap > 0;", conn)
symbols = df_stocks['symbol'].tolist()
tickers = [f"{sym}.BK" for sym in symbols]

print(f"⏳ กำลังดึงข้อมูลราคาประวัติศาสตร์ 1 ปี ของหุ้น {len(symbols)} ตัว...")
# ดึงข้อมูลย้อนหลัง 1 ปี
hist_data = yf.download(tickers, period="1y", progress=False)

# ==========================================
# 2. Calculate & Plot SET Index (Simulated)
# ==========================================
print_topic("Calculate SET Index (Custom Market-Cap Weighted)")

# ดึงราคาปิด (Close) ของทุกตัว
df_close = hist_data['Close'].copy()
df_close.columns = [c.replace('.BK', '') for c in df_close.columns]

# คำนวณผลตอบแทนรายวัน (Daily Return) ของหุ้นแต่ละตัว
df_returns = df_close.pct_change().dropna()

# คำนวณน้ำหนัก (Weight) ของหุ้นแต่ละตัวจาก Market Cap
total_mcap = df_stocks['market_cap'].sum()
df_stocks['weight'] = df_stocks['market_cap'] / total_mcap

# จัด index ของ weight ให้ตรงกับ columns ของ df_returns
weights = df_stocks.set_index('symbol')['weight']
# กรองเฉพาะ weight ของหุ้นที่มีใน df_returns
weights = weights[df_returns.columns]
# ปรับ weight รวมให้เป็น 1 อีกครั้ง (กรณีมีหุ้นบางตัวดึงราคาไม่ได้)
weights = weights / weights.sum()

# คำนวณผลตอบแทนของ Index รายวัน = Sum(Return หุ้น * Weight หุ้น)
index_daily_returns = (df_returns * weights).sum(axis=1)

# สร้าง Index โดยให้วันแรกมีค่า = 1000 จุด
# สูตร: Index ปัจจุบัน = Index ก่อนหน้า * (1 + Daily Return)
custom_set_index = 1000 * (1 + index_daily_returns).cumprod()

print("✅ คำนวณดัชนีจำลอง (Custom SET Index) สำเร็จ! (จุดเริ่มต้น 1000 จุด)")
display(pd.DataFrame({"Custom SET Index": custom_set_index}).tail())

print_topic("Plot SET Index")
plt.figure(figsize=(12, 6))
plt.plot(custom_set_index.index, custom_set_index.values, color='blue', linewidth=2)
plt.title('Simulated SET Index (Market-Cap Weighted) - 1 Year', fontsize=14)
plt.xlabel('Date')
plt.ylabel('Index Value (Base 1000)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.fill_between(custom_set_index.index, custom_set_index.values, 900, color='blue', alpha=0.1)
plt.ylim(custom_set_index.min() * 0.95, custom_set_index.max() * 1.05)
plt.show()

# ==========================================
# 3. Plot Candlestick of any stocks
# ==========================================
print_topic("Plot Candlestick of any stocks (ตัวอย่าง: PTT)")

# เลือกหุ้นมา 1 ตัว (เช่น PTT)
target_stock = "PTT.BK"
df_candle = hist_data.xs(target_stock, axis=1, level=1) if isinstance(hist_data.columns, pd.MultiIndex) else hist_data

# สำหรับ yfinance เวอร์ชั่นใหม่ที่ MultiIndex อาจจะสลับชั้น
if 'Close' in hist_data.columns.levels[0]:
    df_candle = pd.DataFrame({
        'Open': hist_data['Open'][target_stock],
        'High': hist_data['High'][target_stock],
        'Low': hist_data['Low'][target_stock],
        'Close': hist_data['Close'][target_stock],
        'Volume': hist_data['Volume'][target_stock]
    }).dropna()

# ใช้ Plotly วาดกราฟแท่งเทียน (Interactive)
fig = go.Figure(data=[go.Candlestick(x=df_candle.index,
                open=df_candle['Open'],
                high=df_candle['High'],
                low=df_candle['Low'],
                close=df_candle['Close'],
                name='Candlestick')])

fig.update_layout(
    title=f'Candlestick Chart of {target_stock.replace(".BK", "")} (1 Year)',
    yaxis_title='Stock Price (THB)',
    xaxis_title='Date',
    template='plotly_white',
    xaxis_rangeslider_visible=False # ปิดแถบเลื่อนด้านล่างให้กราฟดูสะอาดตา
)

fig.show()
# Out:
# ⏳ กำลังดึงข้อมูลราคาประวัติศาสตร์ 1 ปี ของหุ้น 102 ตัว...
# ### 🎯 Calculate SET Index (Custom Market-Cap Weighted)
# ✅ คำนวณดัชนีจำลอง (Custom SET Index) สำเร็จ! (จุดเริ่มต้น 1000 จุด)
#             Custom SET Index
# Date
# 2026-02-20       1442.415101
# 2026-02-23       1451.499557
# 2026-02-24       1462.655306
# 2026-02-25       1494.249407
# 2026-02-26       1509.598388
# ### 🎯 Plot SET Index
# ### 🎯 Plot Candlestick of any stocks (ตัวอย่าง: PTT)

# %%
# ==========================================
# 1. แก้ไข Schema (เพิ่มคอลัมน์สถานะดัชนี)
# ==========================================
cur.execute("""
    ALTER TABLE stocks 
    ADD COLUMN IF NOT EXISTS is_set50 BOOLEAN DEFAULT FALSE,
    ADD COLUMN IF NOT EXISTS is_set100 BOOLEAN DEFAULT FALSE,
    ADD COLUMN IF NOT EXISTS is_mai BOOLEAN DEFAULT FALSE;
""")
print("✅ อัปเดตโครงสร้างตารางรองรับ SET50, SET100 แล้ว")

# ==========================================
# 2. อัปเดตข้อมูล SET50 / SET100
# ==========================================
set50_symbols = [
    "ADVANC", "AOT", "BBL", "BDMS", "BEM", "BGRIM", "BH", "BTS", "CBG", "CPALL", 
    "CPF", "CPN", "CRC", "DELTA", "EA", "EGCO", "GLOBAL", "GPSC", "GULF", "HMPRO", 
    "INTUCH", "IVL", "KBANK", "KTB", "KTC", "LH", "MINT", "MTC", "OR", "OSP", 
    "PTT", "PTTEP", "PTTGC", "RATCH", "SAWAD", "SCB", "SCC", "SCGP", "TISCO", "TOP", 
    "TRUE", "TTB", "TU", "WHA"
]

cur.execute("UPDATE stocks SET is_set50 = FALSE, is_set100 = TRUE;") 
for sym in set50_symbols:
    cur.execute("UPDATE stocks SET is_set50 = TRUE WHERE symbol = %s;", (sym,))

# ==========================================
# 3. เตรียมข้อมูลและคำนวณ Index
# ==========================================
df_stocks = pd.read_sql("""
    SELECT symbol, market_cap, is_set50, is_set100, sector_name 
    FROM stocks st JOIN sectors s ON st.sector_id = s.sector_id 
    WHERE market_cap > 0;
""", conn)

tickers = [f"{sym}.BK" for sym in df_stocks['symbol']]
print("⏳ กำลังดึงข้อมูลราคาประวัติศาสตร์ 1 ปี...")
hist_data = yf.download(tickers, period="1y", progress=False)['Close']
hist_data.columns = [c.replace('.BK', '') for c in hist_data.columns]
df_returns = hist_data.pct_change().dropna()

# ฟังก์ชันคำนวณ Index
def calculate_index(target_symbols):
    valid_syms = [s for s in target_symbols if s in df_returns.columns]
    if not valid_syms: return None
    subset_mcap = df_stocks[df_stocks['symbol'].isin(valid_syms)].set_index('symbol')['market_cap']
    weights = subset_mcap / subset_mcap.sum()
    idx_returns = (df_returns[valid_syms] * weights).sum(axis=1)
    return 1000 * (1 + idx_returns).cumprod() # เริ่มที่ 1000 จุด

set_index = calculate_index(df_stocks['symbol'].tolist())
set50_index = calculate_index(df_stocks[df_stocks['is_set50'] == True]['symbol'].tolist())
set100_index = calculate_index(df_stocks[df_stocks['is_set100'] == True]['symbol'].tolist())
bank_index = calculate_index(df_stocks[df_stocks['sector_name'] == 'BANK']['symbol'].tolist())
energ_index = calculate_index(df_stocks[df_stocks['sector_name'] == 'ENERG']['symbol'].tolist())

# ==========================================
# 4. พล็อตกราฟเปรียบเทียบดัชนี
# ==========================================
print_topic("Plot SET, SET50, SET100 and Sector Indices")

plt.figure(figsize=(12, 6))
plt.plot(set_index, label='SET Market', color='black', linewidth=2)
plt.plot(set50_index, label='SET50', color='blue', linestyle='--')
plt.plot(set100_index, label='SET100', color='green', linestyle=':')
if bank_index is not None: plt.plot(bank_index, label='BANK Sector', alpha=0.7)
if energ_index is not None: plt.plot(energ_index, label='ENERG Sector', alpha=0.7)

plt.title('Simulated Indices Comparison (Base 1000)')
plt.legend()
plt.grid(True, alpha=0.5)
plt.show()

# ==========================================
# 5. หาหุ้นที่วิ่งตาม SET มากที่สุด (Correlation)
# ==========================================
print_topic("Which stocks move nearest to the SET index most?")
set_daily_returns = set_index.pct_change().dropna()

correlations = {sym: df_returns[sym].corr(set_daily_returns) for sym in df_returns.columns}
df_corr = pd.DataFrame.from_dict(correlations, orient='index', columns=['Correlation']).sort_values(by='Correlation', ascending=False)

print("🏆 5 อันดับวิ่งตามตลาดมากที่สุด (Correlation ใกล้ 1.0):")
display(df_corr.head(5))

print("\n🔻 5 อันดับวิ่งไม่สนตลาด (Correlation ต่ำสุด):")
display(df_corr.tail(5))
# Out:
# ✅ อัปเดตโครงสร้างตารางรองรับ SET50, SET100 แล้ว
# ⏳ กำลังดึงข้อมูลราคาประวัติศาสตร์ 1 ปี...
# ### 🎯 Plot SET, SET50, SET100 and Sector Indices
# ### 🎯 Which stocks move nearest to the SET index most?
# 🏆 5 อันดับวิ่งตามตลาดมากที่สุด (Correlation ใกล้ 1.0):
#        Correlation
# DELTA     0.850726
# GULF      0.674929
# MTC       0.575473
# AWC       0.574727
# CPALL     0.549805
# 🔻 5 อันดับวิ่งไม่สนตลาด (Correlation ต่ำสุด):
#        Correlation
# THG       0.194938
# ONEE      0.168921
# XPG       0.154027
# SUPER     0.138300
# RS        0.076877
