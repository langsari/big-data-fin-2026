# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5433/financialapi_db"
)

engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5433/financialapi_db)

# %%
symbols_df = pd.DataFrame({
    "symbol": ["TU"],
    "market": ["SET"] 
})

symbols = symbols_df["symbol"].tolist()

# %%
all_data = []

for symbol in symbols:
    try:
        data = market.get_candlestick(
            symbol=symbol,
            interval="1d",
            limit=260
        )

        df = pd.DataFrame(data)
        df["symbol"] = symbol
        df["date"] = pd.to_datetime(df["time"], unit="s")
        all_data.append(df)

        print(f"✅ {symbol} OK")

    except Exception as e:
        print(f"❌ {symbol} error:", e)

# ⚠️ concat เฉพาะตอนที่มีข้อมูล
if all_data:
    prices_df = pd.concat(all_data, ignore_index=True)
else:
    prices_df = pd.DataFrame()
# Out:
# ❌ TU error: name 'market' is not defined

# %%
# !pip install settrade-v2

# %%
from settrade_v2 import Investor

investor = Investor(
    app_id="YZ6Qn7ZJWsjSMFNY",
    app_secret="BQ25/nEgRW2r8nJlSXzW4RlZEIlh/XR2mGAbDBnQuNs=",
    app_code="SANDBOX",
    broker_id="SANDBOX"
)

market = investor.MarketData()

# %%
symbols_df = pd.DataFrame({
    "symbol": ["TU"],
    "market": ["SET"] 
})

symbols = symbols_df["symbol"].tolist()

# %%
all_data = []

for symbol in symbols:
    try:
        data = market.get_candlestick(
            symbol=symbol,
            interval="1d",
            limit=260
        )

        df = pd.DataFrame(data)
        df["symbol"] = symbol
        df["date"] = pd.to_datetime(df["time"], unit="s")
        all_data.append(df)

        print(f"✅ {symbol} OK")

    except Exception as e:
        print(f"❌ {symbol} error:", e)

# ⚠️ concat เฉพาะตอนที่มีข้อมูล
if all_data:
    prices_df = pd.concat(all_data, ignore_index=True)
else:
    prices_df = pd.DataFrame()
# Out:
# ❌ TU error: An invalid response was received from the upstream server

# %%
import time

for symbol in symbols:
    try:
        data = market.get_candlestick(
            symbol=symbol,
            interval="1d",
            limit=260
        )

        if not data:
            print(f"⚠️ {symbol} no data")
            continue

        df = pd.DataFrame(data)
        df["symbol"] = symbol
        df["date"] = pd.to_datetime(df["time"], unit="s")
        all_data.append(df)

        print(f"✅ {symbol} OK")
        time.sleep(1)  # ⬅️ สำคัญมาก

    except Exception as e:
        print(f"❌ {symbol} error:", e)
        time.sleep(3)  # ⬅️ รอแล้วลองใหม่รอบหน้า
# Out:
# ❌ TU error: An invalid response was received from the upstream server

# %%
market.get_candlestick(symbol="KBANK", interval="1d", limit=10)
# Out:
# {'lastSequence': 1995880,
#  'time': [1772384400],
#  'open': [198.0],
#  'high': [199.0],
#  'low': [197.5],
#  'close': [199.0],
#  'volume': [1243000],
#  'value': [246478700.0]}

# %%
all_data = []

for symbol in symbols:
    try:
        data = market.get_candlestick(
            symbol=symbol,
            interval="1d",
            limit=260
        )

        df = pd.DataFrame(data)
        df["symbol"] = symbol
        df["date"] = pd.to_datetime(df["time"], unit="s")
        all_data.append(df)

        print(f"✅ {symbol} OK")

    except Exception as e:
        print(f"❌ {symbol} error:", e)

# ⚠️ concat เฉพาะตอนที่มีข้อมูล
if all_data:
    prices_df = pd.concat(all_data, ignore_index=True)
else:
    prices_df = pd.DataFrame()
# Out:
# ✅ TU OK

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5433/financialapi_db"
)

engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost:5433/financialapi_db)

# %%
import pandas as pd

pd.read_sql("""
SELECT table_name, column_name, data_type
FROM information_schema.columns
WHERE table_name IN ('stocks', 'prices')
ORDER BY table_name, ordinal_position;
""", engine)
# Out:
#    table_name  column_name data_type
# 0      prices     price_id   integer
# 1      prices     stock_id   integer
# 2      prices   trade_date      date
# 3      prices         open   numeric
# 4      prices         high   numeric
# 5      prices          low   numeric
# 6      prices        close   numeric
# 7      prices       volume    bigint
# 8      stocks     stock_id   integer
# 9      stocks       symbol      text
# 10     stocks  category_id   integer

# %%
from sqlalchemy import text

with engine.begin() as conn:
    conn.execute(text("""
        INSERT INTO stocks (symbol)
        VALUES
        ('AOT'),
        ('ADVANC'),
        ('BDMS'),
        ('BEM'),
        ('BGRIM'),
        ('BH'),
        ('BJC'),
        ('BTS'),
        ('CBG'),
        ('CPALL'),
        ('CPF'),
        ('CPN'),
        ('CRC'),
        ('DELTA'),
        ('EA'),
        ('GULF'),
        ('INTUCH'),
        ('KBANK'),
        ('KTB'),
        ('PTT')
        ON CONFLICT (symbol) DO NOTHING;
    """))

# %%
# ตรวจตาราง Stocks
stocks_df = pd.read_sql("SELECT * FROM stocks;", engine)
stocks_df
# Out:
#     stock_id  symbol  category_id
# 0          1    GULF          1.0
# 1          3   CPALL          2.0
# 2          6    BDMS          3.0
# 3          7  ADVANC          4.0
# 4          2     AOT          5.0
# 5         12     BEM          NaN
# 6         13   BGRIM          NaN
# 7         14      BH          NaN
# 8         15     BJC          NaN
# 9         16     BTS          NaN
# 10        17     CBG          NaN
# 11        19     CPF          NaN
# 12        20     CPN          NaN
# 13        21     CRC          NaN
# 14        22   DELTA          NaN
# 15        23      EA          NaN
# 16        25  INTUCH          NaN
# 17        26   KBANK          NaN
# 18        27     KTB          NaN
# 19        28     PTT          NaN

# %%
pd.read_sql("SELECT * FROM categories", engine)
# Out:
#    category_id      category_name
# 0            1             Energy
# 1            2           Commerce
# 2            3         Healthcare
# 3            4  Telecommunication
# 4            5     Transportation

# %%
from sqlalchemy import text

with engine.begin() as conn:
    conn.execute(text("""

    INSERT INTO categories (category_name)
    VALUES
    ('Finance'),
    ('Technology')
    ON CONFLICT DO NOTHING;

    """))

# %%
from sqlalchemy import text

with engine.begin() as conn:
    conn.execute(text("""

    UPDATE stocks SET category_id = 5 WHERE symbol='BEM';
    UPDATE stocks SET category_id = 1 WHERE symbol='BGRIM';
    UPDATE stocks SET category_id = 3 WHERE symbol='BH';
    UPDATE stocks SET category_id = 2 WHERE symbol='BJC';
    UPDATE stocks SET category_id = 5 WHERE symbol='BTS';
    UPDATE stocks SET category_id = 2 WHERE symbol='CBG';
    UPDATE stocks SET category_id = 2 WHERE symbol='CPF';
    UPDATE stocks SET category_id = 2 WHERE symbol='CPN';
    UPDATE stocks SET category_id = 2 WHERE symbol='CRC';
    UPDATE stocks SET category_id = 7 WHERE symbol='DELTA';
    UPDATE stocks SET category_id = 1 WHERE symbol='EA';
    UPDATE stocks SET category_id = 4 WHERE symbol='INTUCH';
    UPDATE stocks SET category_id = 6 WHERE symbol='KBANK';
    UPDATE stocks SET category_id = 6 WHERE symbol='KTB';
    UPDATE stocks SET category_id = 1 WHERE symbol='PTT';

    """))

# %%
query = """
SELECT s.symbol, c.category_name
FROM stocks s
JOIN categories c
ON s.category_id = c.category_id
ORDER BY s.symbol
"""
pd.read_sql(query, engine)
# Out:
#     symbol      category_name
# 0   ADVANC  Telecommunication
# 1      AOT     Transportation
# 2     BDMS         Healthcare
# 3      BEM     Transportation
# 4    BGRIM             Energy
# 5       BH         Healthcare
# 6      BJC           Commerce
# 7      BTS     Transportation
# 8      CBG           Commerce
# 9    CPALL           Commerce
# 10     CPF           Commerce
# 11     CPN           Commerce
# 12     CRC           Commerce
# 13   DELTA         Technology
# 14      EA             Energy
# 15    GULF             Energy
# 16  INTUCH  Telecommunication
# 17   KBANK            Finance
# 18     KTB            Finance
# 19     PTT             Energy

# %%
# สร้าง mapping ระหว่าง symbol → stock_id
stock_map = (
    stocks_df
    .set_index("symbol")["stock_id"]
    .to_dict()
)

stock_map
# Out:
# {'GULF': 1,
#  'CPALL': 3,
#  'BDMS': 6,
#  'ADVANC': 7,
#  'AOT': 2,
#  'BEM': 12,
#  'BGRIM': 13,
#  'BH': 14,
#  'BJC': 15,
#  'BTS': 16,
#  'CBG': 17,
#  'CPF': 19,
#  'CPN': 20,
#  'CRC': 21,
#  'DELTA': 22,
#  'EA': 23,
#  'INTUCH': 25,
#  'KBANK': 26,
#  'KTB': 27,
#  'PTT': 28}

# %%
all_prices = []

for _, row in stocks_df.iterrows():
    
    symbol = row["symbol"]
    stock_id = row["stock_id"]
    
    try:
        df = investor.MarketData.get_candlestick(
            symbol=symbol,
            interval="1d",
            start=start_date.strftime("%Y-%m-%d"),
            end=end_date.strftime("%Y-%m-%d")
        )

        df = pd.DataFrame(df)

        df["stock_id"] = stock_id
        df["symbol"] = symbol

        all_prices.append(df)

        print("Loaded:", symbol)

    except Exception as e:
        print("Error:", symbol)
# Out:
# Error: GULF
# Error: CPALL
# Error: BDMS
# Error: ADVANC
# Error: AOT
# Error: BEM
# Error: BGRIM
# Error: BH
# Error: BJC
# Error: BTS
# Error: CBG
# Error: CPF
# Error: CPN
# Error: CRC
# Error: DELTA
# Error: EA
# Error: INTUCH
# Error: KBANK
# Error: KTB
# Error: PTT

# %%
from settrade_v2 import Investor

investor = Investor(
    app_id="aVtejKPRDHZ3LE8N",
    app_secret="Z94lVaLw06yYcUWmPFRuroz7H4M5S9rSv/NPHhMLaBM=",
    broker_id="SANDBOX",
    app_code="SANDBOX"
)

# %%
market = investor.MarketData()

all_prices = []

for _, row in stocks_df.iterrows():

    symbol = row["symbol"]
    stock_id = row["stock_id"]

    try:

        df = market.get_candlestick(
            symbol=symbol,
            interval="1d"
        )

        df = pd.DataFrame(df)

        df["stock_id"] = stock_id
        df["symbol"] = symbol

        all_prices.append(df)

        print("Loaded:", symbol)

    except Exception as e:

        print("Error:", symbol, e)
# Out:
# Loaded: GULF
# Loaded: CPALL
# Loaded: BDMS
# Loaded: ADVANC
# Loaded: AOT
# Loaded: BEM
# Loaded: BGRIM
# Loaded: BH
# Loaded: BJC
# Loaded: BTS
# Loaded: CBG
# Loaded: CPF
# Loaded: CPN
# Loaded: CRC
# Loaded: DELTA
# Loaded: EA
# Error: INTUCH Symbol not found [INTUCH]
# Loaded: KBANK
# Loaded: KTB
# Loaded: PTT

# %%
market.get_candlestick(
    symbol="PTT",
    interval="1d"
)
# Out:
# {'lastSequence': 0,
#  'time': [1707757200,
#   1707843600,
#   1707930000,
#   1708016400,
#   1708275600,
#   1708362000,
#   1708448400,
#   1708534800,
#   1708621200,
#   1708966800,
#   1709053200,
#   1709139600,
#   1709226000,
#   1709485200,
#   1709571600,
#   1709658000,
#   1709744400,
#   1709830800,
#   1710090000,
#   1710176400,
#   1710262800,
#   1710349200,
#   1710435600,
#   1710694800,
#   1710781200,
#   1710867600,
#   1710954000,
#   1711040400,
#   1711299600,
#   1711386000,
#   1711472400,
#   1711558800,
#   1711645200,
#   1711904400,
#   1711990800,
#   1712077200,
#   1712163600,
#   1712250000,
#   1712595600,
#   1712682000,
#   1712768400,
#   1713286800,
#   1713373200,
#   1713459600,
#   1713718800,
#   1713805200,
#   1713891600,
#   1713978000,
#   1714064400,
#   1714323600,
#   1714410000,
#   1714582800,
#   1714669200,
#   1715014800,
#   1715101200,
#   1715187600,
#   1715274000,
#   1715533200,
#   1715619600,
#   1715706000,
# ...

# %%
prices_df = pd.concat(all_prices, ignore_index=True)

prices_df.head()
# Out:
#    lastSequence        time   open   high    low  close     volume  value  \
# 0             0  1743613200  49.25  50.50  48.75  48.75   89811523      0
# 1             0  1743699600  48.00  48.25  45.00  45.00   90093986      0
# 2             0  1744045200  39.00  41.75  38.50  40.00  112546387      0
# 3             0  1744131600  40.50  43.25  39.75  42.25   92188347      0
# 4             0  1744218000  45.50  47.50  44.50  46.00   65247520      0
#
#    stock_id symbol
# 0         1   GULF
# 1         1   GULF
# 2         1   GULF
# 3         1   GULF
# 4         1   GULF

# %%
prices_df.shape
# Out:
# (9222, 10)

# %%
prices_df.columns
# Out:
# Index(['lastSequence', 'time', 'open', 'high', 'low', 'close', 'volume',
#        'value', 'stock_id', 'symbol'],
#       dtype='object')

# %%
prices_df = prices_df.rename(columns={
    "date":"trade_date"
})

# %%
prices_df.to_sql(
    "prices",
    engine,
    if_exists="append",
    index=False
)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2118, in Connection._exec_insertmany_context(self, dialect, context)
#    2117     else:
# -> 2118         dialect.do_execute(
#    2119             cursor,
#    2120             sub_stmt,
#    2121             sub_params,
#    2122             context,
#    2123         )
#    2125 except BaseException as e:
#
# File /opt/anaconda3/lib/python3.13/site-packages/sqlalchemy/engine/default.py:951, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     950 def do_execute(self, cursor, statement, parameters, context=None):
# --> 951     cursor.execute(statement, parameters)
#
# UndefinedColumn: column "lastSequence" of relation "prices" does not exist
# LINE 1: INSERT INTO prices ("lastSequence", time, open, high, low, c...
# ...
