# %% [markdown]
# #### Stock Data Analysis (From Database)
#
# This notebook loads historical stock data from PostgreSQL
# and performs basic analysis and visualization.

# %%
import pandas as pd
import psycopg2
import matplotlib.pyplot as plt

# %%
conn = psycopg2.connect(
    host="127.0.0.1",
    port="5432",
    dbname="stock_market",
    user="postgres",
    password="admin"
)

# %%
query = """
SELECT date, open, high, low, close, volume
FROM stocks
WHERE symbol = 'AOT'
ORDER BY date
"""

# %%
import psycopg2

conn = psycopg2.connect(
    host="127.0.0.1",
    port="5432",
    dbname="stock_api",
    user="postgres",
    password="admin"
)

cur = conn.cursor()
cur.execute("""
SELECT table_name 
FROM information_schema.tables 
WHERE table_schema = 'public';
""")

cur.fetchall()
# Out:
# [('stock_quotes',), ('stock_ohlc',)]

# %%
query = """
SELECT
    date,
    open,
    high,
    low,
    close,
    volume
FROM stock_ohlc
WHERE symbol = 'AOT'
ORDER BY date
"""

# %%
conn.rollback()
