# %% [markdown]
# ## Stock API Ingestion
# ดึงข้อมูลราคาหุ้นจาก Settrade API

# %%
pip install settrade-v2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from settrade_v2 import Investor
import pandas as pd
from datetime import datetime, timedelta

# %%
## Settrade Sandbox Credentials
APP_ID = "K2JnAs0pc2Pzi1Pz"
APP_SECRET = "f3myG7DczEPZcE93KKayywR66NQugQ4VpSH0DkJcWxc="
BROKER_ID = "SANDBOX"
APP_CODE = "SANDBOX"

# %%
#ตรวจสอบ
investor = Investor(
    app_id=APP_ID,
    app_secret=APP_SECRET,
    broker_id=BROKER_ID,
    app_code=APP_CODE,
    is_auto_queue=False
)

print("API Connected")
# Out:
# API Connected

# %%
#เรียก Market Data
mkt_data = investor.MarketData()

# %%
# ดึงข้อมูลหุ้น AOT
quote = mkt_data.get_quote_symbol("AOT")

from pprint import pprint
pprint(quote)
# Out:
# {'aumSize': None,
#  'average': None,
#  'change': None,
#  'eps': 1.26877,
#  'exchange': None,
#  'exercisePrice': None,
#  'exerciseRatio': None,
#  'high': None,
#  'impliedVolatility': None,
#  'inav': None,
#  'instrumentType': 'STOCK',
#  'intrinsicValue': None,
#  'last': None,
#  'lastTradingDate': None,
#  'low': None,
#  'marketStatus': 'Open1',
#  'maturityDate': None,
#  'moneyness': None,
#  'pbv': 5.7,
#  'pe': 41.18,
#  'percentChange': None,
#  'percentYield': 1.55,
#  'securityType': 'CS',
#  'status': 'S,L',
#  'symbol': 'AOT',
#  'theoretical': None,
#  'toLastTrade': None,
#  'totalBuyVolume': 0,
#  'totalNoSideVolume': 0,
#  'totalSellVolume': 0,
#  'totalVolume': 0,
#  'underlying': None,
#  'underlyingPrice': None}

# %%
from settrade_v2 import Investor
import pandas as pd
from datetime import datetime, timedelta

investor = Investor(
    app_id=APP_ID,
    app_secret=APP_SECRET,
    broker_id=BROKER_ID,
    app_code=APP_CODE,
    is_auto_queue=False
)

print("API Connected")
# Out:
# API Connected

# %%
market = investor.MarketData()

# %%
dir(market)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_ctx',
#  'get_candlestick',
#  'get_quote_symbol',
#  'market_url']

# %%
raw_data = market.get_quote_symbol("AOT")
raw_data
# Out:
# {'instrumentType': 'STOCK',
#  'symbol': 'AOT',
#  'high': None,
#  'low': None,
#  'last': None,
#  'average': None,
#  'change': None,
#  'percentChange': None,
#  'totalVolume': 0,
#  'totalBuyVolume': 0,
#  'totalSellVolume': 0,
#  'totalNoSideVolume': 0,
#  'status': 'S,L',
#  'marketStatus': 'Open1',
#  'securityType': 'CS',
#  'eps': 1.26877,
#  'pe': 41.18,
#  'pbv': 5.7,
#  'percentYield': 1.55,
#  'maturityDate': None,
#  'exercisePrice': None,
#  'underlying': None,
#  'underlyingPrice': None,
#  'intrinsicValue': None,
#  'theoretical': None,
#  'moneyness': None,
#  'lastTradingDate': None,
#  'toLastTrade': None,
#  'exerciseRatio': None,
#  'impliedVolatility': None,
#  'exchange': None,
#  'aumSize': None,
#  'inav': None}

# %%
import pandas as pd

df = pd.DataFrame([raw_data])
df
# Out:
#   instrumentType symbol  high   low  last average change percentChange  \
# 0          STOCK    AOT  None  None  None    None   None          None
#
#    totalVolume  totalBuyVolume  ...  intrinsicValue  theoretical moneyness  \
# 0            0               0  ...            None         None      None
#
#   lastTradingDate toLastTrade  exerciseRatio  impliedVolatility  exchange  \
# 0            None        None           None               None      None
#
#    aumSize  inav
# 0     None  None
#
# [1 rows x 33 columns]

# %%
#เหตุผลที่ข้อมูลเป็นค่า None:
#ข้อมูลราคาหุ้นบางรายการเป็นค่า None เนื่องจากมีการดึงข้อมูลนอกเวลาซื้อขายของตลาดหลักทรัพย์ ทำให้ระบบไม่แสดงราคาการซื้อขายและปริมาณการซื้อขายในช่วงเวลาดังกล่าว
