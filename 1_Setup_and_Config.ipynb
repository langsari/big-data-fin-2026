# %%
# Cell 1: ข้อมูลการเชื่อมต่อ (Config)
DB_CONFIG = {
    "host": "localhost",
    "database": "financial_db",
    "user": "postgres",
    "password": "1234",
    "port": 5432
}

API_CONFIG = {
    "app_id": "gfR7Svj8aaEZWEJp",
    "app_secret": "APiguzgG/8QN4NMqnZy7o319e+QiNPdTC/yTpU1AgOjN",
    "app_code": "712441N", # บัญชีจริง KTX
    "broker_id": "KTX"
}

# %store DB_CONFIG API_CONFIG
print("✅ 1. บันทึก Configuration สำเร็จ (หัวข้อ 2.1)")
# Out:
# Stored 'DB_CONFIG' (dict)
# Stored 'API_CONFIG' (dict)
# ✅ 1. บันทึก Configuration สำเร็จ (หัวข้อ 2.1)

# %%
# !java -version
# Out:
# java version "26.0.1" 2026-04-21
# Java(TM) SE Runtime Environment (build 26.0.1+8-34)
# Java HotSpot(TM) 64-Bit Server VM (build 26.0.1+8-34, mixed mode, sharing)
